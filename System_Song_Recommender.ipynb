# %% [markdown]
# # Construyendo una canción recomendada

# %% [markdown]
# ###1. Importar Librerias
#
# ---

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.externals import joblib

# %% [markdown]
# ###2. Cargar datos musicales
#
# ---

# %%
#Read userid-songid-listen_count triplets
#This step might take time to download data from external sources
triplets_file = 'https://static.turi.com/datasets/millionsong/10000.txt'
songs_metadata_file = 'https://static.turi.com/datasets/millionsong/song_data.csv'

song_df_1 = pandas.read_table(triplets_file,header=None)
song_df_1.columns = ['user_id', 'song_id', 'listen_count']

#Read song  metadata
song_df_2 =  pandas.read_csv(songs_metadata_file)

#Merge the two dataframes above to create input dataframe for recommender systems
song_df = pandas.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   after removing the cwd from sys.path.

# %% [markdown]
# ### 3. Explorar datos
#
# ---
#
# Los datos de música muestran cuántas veces un usuario escuchó una canción, así como los detalles de la canción.

# %%
song_df.head()
# Out:
#                                     user_id  ...  year
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...     0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...  1976
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...  2007
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...  2005
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...  1999
#
# [5 rows x 7 columns]

# %%
song_df
# Out:
#                                        user_id  ...                                               song
# 0     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                            The Cove - Jack Johnson
# 1     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                    Entre Dos Aguas - Paco De Lucia
# 2     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                              Stronger - Kanye West
# 3     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                      Constellations - Jack Johnson
# 4     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                        Learn To Fly - Foo Fighters
# 5     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...  Apuesta Por El Rock 'N' Roll - Héroes del Sile...
# 6     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                          Paper Gangsta - Lady GaGa
# 7     b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                      Stacked Actors - Foo Fighters
# ...

# %% [markdown]
# ### 4. Longitud del conjunto de datos
#
# ---

# %%
len(song_df)
# Out:
# 2000000

# %% [markdown]
# ###5. Crear un subconjunto del conjunto de datos
#
# ---

# %%
song_df = song_df.head(10000)

#Merge song title and artist_name columns to make a merged column
song_df['song'] = song_df['title'].map(str) + " - " + song_df['artist_name']

# %% [markdown]
# ### 6. Mostrando las canciones más populares en el conjunto de datos
#
# ---

# %%
song_grouped = song_df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage']  = song_grouped['listen_count'].div(grouped_sum)*100
song_grouped.sort_values(['listen_count', 'song'], ascending = [0,1])
# Out:
#                                                    song  ...  percentage
# 3660                           Sehr kosmisch - Harmonia  ...        0.45
# 4678                                       Undo - Björk  ...        0.32
# 5105                     You're The One - Dwight Yoakam  ...        0.32
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...  ...        0.28
# 3655                              Secrets - OneRepublic  ...        0.28
# 4378                           The Scientist - Coldplay  ...        0.27
# 4712                       Use Somebody - Kings Of Leon  ...        0.27
# 3476                            Revelry - Kings Of Leon  ...        0.26
# 1387                     Fireflies - Charttraxx Karaoke  ...        0.24
# 1862  Horn Concerto No. 4 in E flat K495: II. Romanc...  ...        0.23
# 1805                           Hey_ Soul Sister - Train  ...        0.22
# 5032                                  Yellow - Coldplay  ...        0.22
# ...

# %% [markdown]
# ###7.  Número de usuarios únicos en el conjunto de datos
#
# ---

# %%
users = song_df['user_id'].unique()

# %%
len(users)
# Out:
# 365

# %% [markdown]
# ###8.  Contar el número de canciones únicas en el conjunto de datos
#
# ---

# %%
songs = song_df['song'].unique()
len(songs)
# Out:
# 5151

# %% [markdown]
# ###9.  Crea una recomendación de canciones.
#
# ---

# %%
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)
print(train_data.head(5))
# Out:
#                                        user_id  ...                                   song
# 7389  94d5bdc37683950e90c56c9b32721edb5d347600  ...          Half Of My Heart - John Mayer
# 9275  1012ecfd277b96487ed8357d02fa8326b13696a5  ...  The Beautiful People - Marilyn Manson
# 2995  15415fa2745b344bce958967c346f2a89f792f63  ...       Sanctify Yourself - Simple Minds
# 5316  ffadf9297a99945c0513cd87939d91d8b602936b  ...       Heart Cooks Brain - Modest Mouse
# 356   5a905f000fc1ff3df7ca807d57edb608863db05d  ...                Rorol - Octopus Project
#
# [5 rows x 8 columns]
